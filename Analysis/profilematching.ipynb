# %% [markdown]
# # **IMPORT LIBRARIES**
# ___
# Import libraries needed for the project.

# %%
# Analysis and modeling 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Saving model
import pickle

# %% [markdown]
# # **LOAD DATA**
# ___
# Load the data we've gathered from SMK Negeri 2 Malang.

# %%
df = pd.read_excel('NILAI_TKJ.xlsx', sheet_name='aplikasi')
df
# Out:
#      No Absen    NIS               Nama Lengkap    A1     A2         A3  \
# 0           1  16986      ADHITYA AMIRUN NADHIF  80.0  85.00  94.500000
# 1           2  16988  AHMAD ZAKI ANDIKA PRATAMA  80.0  82.50  94.000000
# 2           3  16989              AKHMAD NIZHAR  78.0  87.00  94.000000
# 3           4  16990     AKHMAD ROSSI SAIFULLAH  75.0  84.00  94.000000
# 4           5  16992      AKMAL CAHYA PAMUNGKAS  76.5  85.50  85.000000
# ..        ...    ...                        ...   ...    ...        ...
# 198        30  16403      MUHAMMAD YOGA PRATAMA  81.0  80.75  89.000000
# 199        31  16411       RAFI ADNAN RAHMADIAN  82.0  84.00  91.000000
# 200        32  16414        RENDY BAGUS SANTOSO  81.0  80.75  86.333333
# 201        33  16427         SINDU PUTRI ANANDA  79.5  82.50  91.333333
# 202        34  16433        YOGA PRATAMA AFANDY  81.5  84.50  84.000000
#
#             A4         A5         A6         A7    A8   A9        A10   A11  \
# 0    80.500000  83.500000  84.500000  80.000000  86.0  0.0   0.000000  4.60
# 1    79.000000  85.500000  90.500000  82.500000  86.0  0.0   0.000000  5.20
# 2    84.000000  87.500000  87.000000  83.500000  86.5  0.0   0.000000  3.20
# 3    80.500000  85.500000  90.000000  82.500000  82.5  0.0   0.000000  7.50
# 4    79.500000  85.000000  81.000000  81.500000  76.5  0.0   0.000000  1.30
# ..         ...        ...        ...        ...   ...  ...        ...   ...
# 198  86.333333  88.000000  89.333333  81.666667   0.0  0.0  82.666667  0.45
# 199  90.333333  93.333333  90.333333  84.333333   0.0  0.0  91.000000  0.70
# 200  84.333333  81.000000  81.333333  79.333333   0.0  0.0  83.000000  4.40
# 201  89.333333  91.000000  88.000000  85.666667   0.0  0.0  91.666667  4.60
# 202  84.333333  84.000000  83.000000  80.666667   0.0  0.0  79.666667  2.10
#
#     Jurusan  Angkatan                    Nama Industri      Jenis Industri
# 0     TKJ 1      2024                    Micromedia hp  Mobile Engineering
# 1     TKJ 1      2024                    Micromedia hp  Mobile Engineering
# 2     TKJ 1      2024                    Micromedia hp  Mobile Engineering
# 3     TKJ 1      2024          Ciliwung Phone Solution  Mobile Engineering
# 4     TKJ 1      2024              FLASH XIAOMI MALANG  Mobile Engineering
# ..      ...       ...                              ...                 ...
# 198   TKJ 3      2023  Fakultas TI Universitas Merdeka  Internet of Things
# 199   TKJ 3      2023                        VOKASI UB  Internet of Things
# 200   TKJ 3      2023                       7 Komputer  Internet of Things
# 201   TKJ 3      2023             Universitas Ma Chung  Internet of Things
# 202   TKJ 3      2023  Fakultas TI Universitas Merdeka  Internet of Things
#
# [203 rows x 18 columns]

# %% [markdown]
# A

# %% [markdown]
# # **EXPLORATORY DATA ANALYSIS**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203 entries, 0 to 202
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   No Absen        203 non-null    int64
#  1   NIS             203 non-null    int64
#  2   Nama Lengkap    203 non-null    object
#  3   A1              203 non-null    float64
#  4   A2              203 non-null    float64
#  5   A3              203 non-null    float64
#  6   A4              203 non-null    float64
#  7   A5              203 non-null    float64
#  8   A6              203 non-null    float64
#  9   A7              203 non-null    float64
#  10  A8              203 non-null    float64
#  11  A9              203 non-null    float64
#  12  A10             203 non-null    float64
#  13  A11             203 non-null    float64
#  14  Jurusan         203 non-null    object
#  15  Angkatan        203 non-null    int64
#  16  Nama Industri   203 non-null    object
#  17  Jenis Industri  203 non-null    object
# dtypes: float64(11), int64(3), object(4)
# memory usage: 28.7+ KB

# %%
df.describe().T
# Out:
#           count          mean         std       min      25%           50%  \
# No Absen  203.0     17.487685    9.905674      1.00      9.0     17.000000
# NIS       203.0  16715.167488  329.809413  16332.00  16383.5  16986.000000
# A1        203.0     79.135468    5.291222     52.50     76.5     80.500000
# A2        203.0     82.248768    2.727802     72.00     80.5     82.000000
# A3        203.0     84.765189   10.654510      0.00     83.0     86.666667
# A4        203.0     82.925287   10.633510      0.00     80.5     84.000000
# A5        203.0     82.375205   10.330060      0.00     80.0     84.000000
# A6        203.0     83.553366   10.939215      0.00     82.0     85.333333
# A7        203.0     81.757800   10.206950      0.00     80.0     82.333333
# A8        203.0     25.654351   37.739674      0.00      0.0      0.000000
# A9        203.0     30.265189   41.492774      0.00      0.0      0.000000
# A10       203.0     27.244663   40.006240      0.00      0.0      0.000000
# A11       203.0      9.668374   22.971767      0.25      3.6      5.400000
# Angkatan  203.0   2023.507389    0.501181   2023.00   2023.0   2024.000000
#
#                    75%           max
# No Absen     26.000000     36.000000
# NIS       17038.000000  17091.000000
# A1           82.375000     90.500000
# A2           84.000000     90.000000
# A3           88.666667     97.000000
# A4           87.833333     95.666667
# A5           86.000000     95.666667
# A6           88.500000     92.666667
# A7           85.000000     98.000000
# A8           76.750000     89.000000
# A9           84.000000     99.000000
# A10          79.333333     95.666667
# A11           8.650000    268.000000
# Angkatan   2024.000000   2024.000000

# %% [markdown]
# Here are several key insight:
#
# - There are no null value nor duplicated value in the dataset.
# -

# %% [markdown]
# # **PROFILE MATCHING MODEL**

# %%
import pandas as pd

# Fungsi untuk membaca data dari file Excel dengan sheet yang bernama 'aplikasi'
def read_data_excel(file_path):
    return pd.read_excel(file_path, sheet_name='aplikasi')

def map_sub_aspek_to_kode():
    # Data berdasarkan informasi yang ada
    data = [
        ("Informatika", "A1"),
        ("Dasar Program Keahlian", "A2"),
        ("Projek Kreatif dan Kewirausahaan", "A3"),
        ("Perencanaan dan Pengalamatan Jaringan", "A4"),
        ("Administrasi Sistem Jaringan", "A5"),
        ("Teknologi Jaringan Kabel dan Nirkabel", "A6"),
        ("Pemasangan dan Konfigurasi Perangkat Jaringan", "A7"),
        ("Samsung Tech Institute", "A8"),
        ("Pemrograman Web", "A9"),
        ("Internet of Things", "A10"),
        ("Jarak", "A11")
    ]
    
    # Membuat dictionary yang memetakan Nama Sub Aspek ke Kode Sub Aspek
    sub_aspek_mapping = {item[0]: item[1] for item in data}
    
    return sub_aspek_mapping

# Fungsi untuk mengonversi nilai rapot dan jarak
def kisaran_rapot(rapot):
    if 95 <= rapot <= 100:
        return 8
    elif 90 <= rapot < 95:
        return 7
    elif 85 <= rapot < 90:
        return 6
    elif 80 <= rapot < 85:
        return 5
    elif 75 <= rapot < 80:
        return 4
    elif 70 <= rapot < 75:
        return 3
    elif 65 <= rapot < 70:
        return 2
    elif 0 <= rapot < 65:
        return 1
    else:
        return 0

def kisaran_jarak(jrk):
    if 0 <= jrk <= 2:
        return 8
    elif 2 < jrk <= 4:
        return 7
    elif 4 < jrk <= 6:
        return 6
    elif 6 < jrk <= 8:
        return 5
    elif 8 < jrk <= 10:
        return 4
    elif 10 < jrk <= 12:
        return 3
    elif 12 < jrk <= 14:
        return 2
    elif jrk > 14:
        return 1
    else:
        return 0

def konversi(sub_aspek):
    konversi_rapot = [kisaran_rapot(sub_aspek[i]) for i in range(10)]  
    konversi_jarak = kisaran_jarak(sub_aspek[10]) 
    return konversi_rapot + [konversi_jarak]

def selisih(sub_aspek, jenis_pkl):
    nilai_siswa = konversi(sub_aspek)

    jenis_pkl_tiap_label = {
        "Mobile Engineering"    : [8, 8, 8, 7, 7, 7, 7, 8, 3, 3, 7],
        "Software Engineering"  : [8, 8, 8, 7, 7, 7, 7, 3, 8, 3, 7],
        "Internet of Things"    : [8, 8, 7, 7, 7, 7, 7, 3, 3, 8, 7]
    }

    nilai_gap_standar_pkl = jenis_pkl_tiap_label[jenis_pkl]
    selisih_profil_pkl = [nilai_siswa[i] - nilai_gap_standar_pkl[i] for i in range(len(nilai_siswa))]
    return [gap(selisih_gap) for selisih_gap in selisih_profil_pkl]

def gap(bbt):
    bobot_gap = {
        0: 9, 1: 8.5, -1: 8, 2: 7.5, -2: 7, 3: 6.5, -3: 6,
        4: 5.5, -4: 5, 5: 4.5, -5: 4, 6: 3.5, -6: 3,
        7: 2.5, -7: 2, 8: 1.5, -8: 1
    }
    return bobot_gap.get(bbt, 0)

def pengurutan_penempatan(sub_aspek, jenis_pkl):
    hasil_bobot_gap = selisih(sub_aspek, jenis_pkl)

    cf = [hasil_bobot_gap[i] for i in range(7) if i != 2]
    sf = hasil_bobot_gap[7:10] + [hasil_bobot_gap[2]]  
    aspek_cf = sum(cf) / len(cf) 
    aspek_sf = sum(sf) / len(sf)
    total_aspek_1 = (aspek_cf * 0.6) + (aspek_sf * 0.4)

    nfl = hasil_bobot_gap[10]  
    total_aspek_2 = nfl 

    return (total_aspek_1 * 0.6) + (total_aspek_2 * 0.4)

# Fungsi utama untuk membaca data dari excel, menghitung dan menambahkan kolom hasil perhitungan
def proses_perhitungan(file_path):
    # Membaca data siswa dari file Excel pada sheet 'aplikasi'
    df = read_data_excel(file_path)

    # Menambahkan kolom hasil perhitungan
    df['Nilai Total'] = None
    df['Penempatan PKL'] = None

    # Menggunakan apply untuk setiap baris, daripada iterrows
    def hitung_penempatan(row):
        sub_aspek = [row[f'A{i}'] for i in range(1, 12)]  # Mengambil data sub aspek

        # Menghitung hasil penempatan untuk masing-masing jenis pkl
        nilai_penempatan = {}
        for jenis_pkl in ["Mobile Engineering", "Software Engineering", "Internet of Things"]:
            nilai_penempatan[jenis_pkl] = pengurutan_penempatan(sub_aspek, jenis_pkl)

        # Menentukan kategori terbaik berdasarkan nilai tertinggi
        kategori_terbaik = max(nilai_penempatan, key=nilai_penempatan.get)
        total = nilai_penempatan[kategori_terbaik]

        return pd.Series([total, kategori_terbaik])

    # Menggunakan apply untuk menghitung hasil penempatan dan total untuk setiap baris
    df[['Nilai Total', 'Penempatan PKL']] = df.apply(hitung_penempatan, axis=1)

    return df

# Simpan hasil perhitungan ke file baru
def simpan_hasil(df, output_file):
    df.to_excel(output_file, index=False)

# Fungsi untuk memproses data dan menyimpan hasil
file_input = 'NILAI_TKJ.xlsx'  # Ganti dengan path file Excel yang sesuai
df_hasil = proses_perhitungan(file_input)
file_output = 'hasil_penempatan.xlsx'  # Ganti dengan nama file output yang diinginkan
simpan_hasil(df_hasil, file_output)

# %% [markdown]
# # **POST-MODELING ANALYSIS**

# %%
hasil = pd.read_excel('hasil_penempatan.xlsx')
hasil
# Out:
#      No Absen    NIS               Nama Lengkap    A1     A2         A3  \
# 0           1  16986      ADHITYA AMIRUN NADHIF  80.0  85.00  94.500000
# 1           2  16988  AHMAD ZAKI ANDIKA PRATAMA  80.0  82.50  94.000000
# 2           3  16989              AKHMAD NIZHAR  78.0  87.00  94.000000
# 3           4  16990     AKHMAD ROSSI SAIFULLAH  75.0  84.00  94.000000
# 4           5  16992      AKMAL CAHYA PAMUNGKAS  76.5  85.50  85.000000
# ..        ...    ...                        ...   ...    ...        ...
# 198        30  16403      MUHAMMAD YOGA PRATAMA  81.0  80.75  89.000000
# 199        31  16411       RAFI ADNAN RAHMADIAN  82.0  84.00  91.000000
# 200        32  16414        RENDY BAGUS SANTOSO  81.0  80.75  86.333333
# 201        33  16427         SINDU PUTRI ANANDA  79.5  82.50  91.333333
# 202        34  16433        YOGA PRATAMA AFANDY  81.5  84.50  84.000000
#
#             A4         A5         A6         A7    A8   A9        A10   A11  \
# 0    80.500000  83.500000  84.500000  80.000000  86.0  0.0   0.000000  4.60
# 1    79.000000  85.500000  90.500000  82.500000  86.0  0.0   0.000000  5.20
# 2    84.000000  87.500000  87.000000  83.500000  86.5  0.0   0.000000  3.20
# 3    80.500000  85.500000  90.000000  82.500000  82.5  0.0   0.000000  7.50
# 4    79.500000  85.000000  81.000000  81.500000  76.5  0.0   0.000000  1.30
# ..         ...        ...        ...        ...   ...  ...        ...   ...
# 198  86.333333  88.000000  89.333333  81.666667   0.0  0.0  82.666667  0.45
# 199  90.333333  93.333333  90.333333  84.333333   0.0  0.0  91.000000  0.70
# 200  84.333333  81.000000  81.333333  79.333333   0.0  0.0  83.000000  4.40
# 201  89.333333  91.000000  88.000000  85.666667   0.0  0.0  91.666667  4.60
# 202  84.333333  84.000000  83.000000  80.666667   0.0  0.0  79.666667  2.10
#
#     Jurusan  Angkatan                    Nama Industri      Jenis Industri  \
# 0     TKJ 1      2024                    Micromedia hp  Mobile Engineering
# 1     TKJ 1      2024                    Micromedia hp  Mobile Engineering
# 2     TKJ 1      2024                    Micromedia hp  Mobile Engineering
# 3     TKJ 1      2024          Ciliwung Phone Solution  Mobile Engineering
# 4     TKJ 1      2024              FLASH XIAOMI MALANG  Mobile Engineering
# ..      ...       ...                              ...                 ...
# 198   TKJ 3      2023  Fakultas TI Universitas Merdeka  Internet of Things
# 199   TKJ 3      2023                        VOKASI UB  Internet of Things
# 200   TKJ 3      2023                       7 Komputer  Internet of Things
# 201   TKJ 3      2023             Universitas Ma Chung  Internet of Things
# 202   TKJ 3      2023  Fakultas TI Universitas Merdeka  Internet of Things
#
#      Nilai Total      Penempatan PKL
# 0           7.40  Mobile Engineering
# 1           7.46  Mobile Engineering
# 2           7.86  Mobile Engineering
# 3           7.00  Mobile Engineering
# 4           7.36  Mobile Engineering
# ..           ...                 ...
# 198         7.66  Internet of Things
# 199         8.02  Internet of Things
# 200         7.22  Internet of Things
# 201         7.70  Internet of Things
# 202         7.56  Internet of Things
#
# [203 rows x 20 columns]

# %%
pkl = hasil['Jenis Industri'] == hasil['Penempatan PKL']
akurasi = pkl.value_counts(normalize=True)
akurasi
# Out:
# True     0.935961
# False    0.064039
# Name: proportion, dtype: float64

# %%
# Hitung frekuensi True dan False dari filter tersebut
counts = pkl.value_counts()

# Plot Pie Chart
plt.figure(figsize=(6,6))
plt.pie(counts, labels=[f"Sama ({counts[True]})", f"Tidak Sama ({counts[False]})"], autopct='%1.1f%%', startangle=90)
plt.title('Proporisi Data yang Sama dan Tidak Sama antara Jenis Industri dan Penempatan PKL')
plt.show()

# %%
total = hasil[hasil['Jenis Industri'] != hasil['Penempatan PKL']]

heatmap_data = pd.crosstab(total['Jenis Industri'], total['Penempatan PKL'])

# Plot Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', fmt='d')
plt.title('Heatmap Frekuensi Jenis Industri vs Penempatan PKL (Data Tidak Sama)')
plt.ylabel('Jenis Industri')
plt.xlabel('Penempatan PKL')
plt.show()

# %% [markdown]
# # **CREATE NEW PACKAGE FOR PROFILE MATCHING MODEL**

# %%
import pandas as pd

class PKLPlacementModel:
    def __init__(self):
        self.sub_aspek_mapping = self.map_sub_aspek_to_kode()

    def map_sub_aspek_to_kode(self):
        # Memetakan nama sub-aspek ke A1-A11
        data = [
            ("Informatika", "A1"),
            ("Dasar Program Keahlian", "A2"),
            ("Projek Kreatif dan Kewirausahaan", "A3"),
            ("Perencanaan dan Pengalamatan Jaringan", "A4"),
            ("Administrasi Sistem Jaringan", "A5"),
            ("Teknologi Jaringan Kabel dan Nirkabel", "A6"),
            ("Pemasangan dan Konfigurasi Perangkat Jaringan", "A7"),
            ("Samsung Tech Institute", "A8"),
            ("Pemrograman Web", "A9"),
            ("Internet of Things", "A10"),
            ("Jarak", "A11")
        ]
        return {item[0]: item[1] for item in data}

    def map_columns_to_A(self, df):
        """
        Fungsi untuk mengganti nama kolom yang sesuai dengan sub-aspek menjadi A1, A2, ..., A11
        Jika kolom sudah menggunakan A1, A2, ..., A11, maka tidak akan diubah.
        """
        sub_aspek = list(self.sub_aspek_mapping.keys())
        A_columns = list(self.sub_aspek_mapping.values())
        
        # Membuat mapping nama kolom yang sesuai dengan sub-aspek
        column_mapping = {sub_aspek[i]: A_columns[i] for i in range(len(sub_aspek))}
        
        # Ganti nama kolom jika kolom tersebut sesuai dengan sub-aspek
        df.columns = [column_mapping.get(col, col) for col in df.columns]
        return df

    def kisaran_rapot(self, rapot):
        if 95 <= rapot <= 100:
            return 8
        elif 90 <= rapot < 95:
            return 7
        elif 85 <= rapot < 90:
            return 6
        elif 80 <= rapot < 85:
            return 5
        elif 75 <= rapot < 80:
            return 4
        elif 70 <= rapot < 75:
            return 3
        elif 65 <= rapot < 70:
            return 2
        elif 0 <= rapot < 65:
            return 1
        else:
            return 0

    def kisaran_jarak(self, jrk):
        if 0 <= jrk <= 2:
            return 8
        elif 2 < jrk <= 4:
            return 7
        elif 4 < jrk <= 6:
            return 6
        elif 6 < jrk <= 8:
            return 5
        elif 8 < jrk <= 10:
            return 4
        elif 10 < jrk <= 12:
            return 3
        elif 12 < jrk <= 14:
            return 2
        elif jrk > 14:
            return 1
        else:
            return 0

    def konversi(self, sub_aspek):
        konversi_rapot = [self.kisaran_rapot(sub_aspek[i]) for i in range(10)]  
        konversi_jarak = self.kisaran_jarak(sub_aspek[10]) 
        return konversi_rapot + [konversi_jarak]

    def gap(self, bbt):
        bobot_gap = {
            0: 9, 1: 8.5, -1: 8, 2: 7.5, -2: 7, 3: 6.5, -3: 6,
            4: 5.5, -4: 5, 5: 4.5, -5: 4, 6: 3.5, -6: 3,
            7: 2.5, -7: 2, 8: 1.5, -8: 1
        }
        return bobot_gap.get(bbt, 0)

    def selisih(self, sub_aspek, jenis_pkl):
        nilai_siswa = self.konversi(sub_aspek)

        jenis_pkl_tiap_label = {
            "Mobile Engineering"	: [8, 8, 8, 7, 7, 7, 7, 8, 3, 3, 7],
            "Software Engineering"	: [8, 8, 8, 7, 7, 7, 7, 3, 8, 3, 7],
            "Internet of Things"	: [8, 8, 7, 7, 7, 7, 7, 3, 3, 8, 7]
        }

        nilai_gap_standar_pkl = jenis_pkl_tiap_label[jenis_pkl]
        selisih_profil_pkl = [nilai_siswa[i] - nilai_gap_standar_pkl[i] for i in range(len(nilai_siswa))]
        return [self.gap(selisih_gap) for selisih_gap in selisih_profil_pkl]

    def pengurutan_penempatan(self, sub_aspek, jenis_pkl):
        hasil_bobot_gap = self.selisih(sub_aspek, jenis_pkl)

        cf = [hasil_bobot_gap[i] for i in range(7) if i != 2]
        sf = hasil_bobot_gap[7:10] + [hasil_bobot_gap[2]]  
        aspek_cf = sum(cf) / len(cf) 
        aspek_sf = sum(sf) / len(sf)
        total_aspek_1 = (aspek_cf * 0.6) + (aspek_sf * 0.4)

        nfl = hasil_bobot_gap[10]  
        total_aspek_2 = nfl 

        return (total_aspek_1 * 0.6) + (total_aspek_2 * 0.4)

    def inference(self, sub_aspek_data):
        nilai_penempatan = {}

        for jenis_pkl in ["Mobile Engineering", "Software Engineering", "Internet of Things"]:
            nilai_penempatan[jenis_pkl] = self.pengurutan_penempatan(sub_aspek_data, jenis_pkl)

        kategori_terbaik = max(nilai_penempatan, key=nilai_penempatan.get)
        total = nilai_penempatan[kategori_terbaik]

        return total, kategori_terbaik

# %% [markdown]
# # **MODEL INFERENCE**

# %%
# Assuming the model is already defined as PKLPlacementModel

# Example input data for 5 individuals
inputs = [
    [80, 85, 94.5, 80.5, 83.5, 84.5, 80, 86, 0, 0, 4.6],  # Individual 1
    [75, 88, 90, 80, 82, 85, 76, 89, 0, 0, 5],            # Individual 2
    [78, 84, 91, 82, 84, 87, 79, 85, 0, 0, 4.8],           # Individual 3
    [81, 86, 93, 81, 84, 85, 78, 88, 0, 0, 5.1],           # Individual 4
    [77, 83, 92, 79, 81, 86, 77, 87, 0, 0, 4.7]            # Individual 5
]

# Instantiate the model
model = PKLPlacementModel()

# Process each individual's data
for i, sub_aspek_input in enumerate(inputs, 1):
    nilai_total, kategori_terbaik = model.inference(sub_aspek_input)
    print(f"Individual {i}:")
    print(f"  Nilai Total: {nilai_total}")
    print(f"  Penempatan PKL terbaik: {kategori_terbaik}")
    print("-" * 30)
# Out:
# Individual 1:
#   Nilai Total: 7.4
#   Penempatan PKL terbaik: Mobile Engineering
# ------------------------------
# Individual 2:
#   Nilai Total: 7.34
#   Penempatan PKL terbaik: Mobile Engineering
# ------------------------------
# Individual 3:
#   Nilai Total: 7.28
#   Penempatan PKL terbaik: Mobile Engineering
# ------------------------------
# Individual 4:
#   Nilai Total: 7.4
#   Penempatan PKL terbaik: Mobile Engineering
# ------------------------------
# Individual 5:
#   Nilai Total: 7.22
#   Penempatan PKL terbaik: Mobile Engineering
# ------------------------------

# %% [markdown]
# ## **SAVING MODEL**

# %%
model_script = """
import pandas as pd 

class PKLPlacementModel:
    def __init__(self):
        self.sub_aspek_mapping = self.map_sub_aspek_to_kode()

    def map_sub_aspek_to_kode(self):
        # Memetakan nama sub-aspek ke A1-A11
        data = [
            ("Informatika", "A1"),
            ("Dasar Program Keahlian", "A2"),
            ("Projek Kreatif dan Kewirausahaan", "A3"),
            ("Perencanaan dan Pengalamatan Jaringan", "A4"),
            ("Administrasi Sistem Jaringan", "A5"),
            ("Teknologi Jaringan Kabel dan Nirkabel", "A6"),
            ("Pemasangan dan Konfigurasi Perangkat Jaringan", "A7"),
            ("Samsung Tech Institute", "A8"),
            ("Pemrograman Web", "A9"),
            ("Internet of Things", "A10"),
            ("Jarak", "A11")
        ]
        return {item[0]: item[1] for item in data}

    def map_columns_to_A(self, df):
        # Fungsi untuk mengganti nama kolom yang sesuai dengan sub-aspek menjadi A1, A2, ..., A11
        # Jika kolom sudah menggunakan A1, A2, ..., A11, maka tidak akan diubah.
		
        sub_aspek = list(self.sub_aspek_mapping.keys())
        A_columns = list(self.sub_aspek_mapping.values())
        
        # Membuat mapping nama kolom yang sesuai dengan sub-aspek
        column_mapping = {sub_aspek[i]: A_columns[i] for i in range(len(sub_aspek))}
        
        # Ganti nama kolom jika kolom tersebut sesuai dengan sub-aspek
        df.columns = [column_mapping.get(col, col) for col in df.columns]
        return df

    def kisaran_rapot(self, rapot):
        if 95 <= rapot <= 100:
            return 8
        elif 90 <= rapot < 95:
            return 7
        elif 85 <= rapot < 90:
            return 6
        elif 80 <= rapot < 85:
            return 5
        elif 75 <= rapot < 80:
            return 4
        elif 70 <= rapot < 75:
            return 3
        elif 65 <= rapot < 70:
            return 2
        elif 0 <= rapot < 65:
            return 1
        else:
            return 0

    def kisaran_jarak(self, jrk):
        if 0 <= jrk <= 2:
            return 8
        elif 2 < jrk <= 4:
            return 7
        elif 4 < jrk <= 6:
            return 6
        elif 6 < jrk <= 8:
            return 5
        elif 8 < jrk <= 10:
            return 4
        elif 10 < jrk <= 12:
            return 3
        elif 12 < jrk <= 14:
            return 2
        elif jrk > 14:
            return 1
        else:
            return 0

    def konversi(self, sub_aspek):
        konversi_rapot = [self.kisaran_rapot(sub_aspek[i]) for i in range(10)]  
        konversi_jarak = self.kisaran_jarak(sub_aspek[10]) 
        return konversi_rapot + [konversi_jarak]

    def gap(self, bbt):
        bobot_gap = {
            0: 9, 1: 8.5, -1: 8, 2: 7.5, -2: 7, 3: 6.5, -3: 6,
            4: 5.5, -4: 5, 5: 4.5, -5: 4, 6: 3.5, -6: 3,
            7: 2.5, -7: 2, 8: 1.5, -8: 1
        }
        return bobot_gap.get(bbt, 0)

    def selisih(self, sub_aspek, jenis_pkl):
        nilai_siswa = self.konversi(sub_aspek)

        jenis_pkl_tiap_label = {
            "Mobile Engineering"	: [8, 8, 8, 7, 7, 7, 7, 8, 3, 3, 7],
            "Software Engineering"	: [8, 8, 8, 7, 7, 7, 7, 3, 8, 3, 7],
            "Internet of Things"	: [8, 8, 7, 7, 7, 7, 7, 3, 3, 8, 7]
        }

        nilai_gap_standar_pkl = jenis_pkl_tiap_label[jenis_pkl]
        selisih_profil_pkl = [nilai_siswa[i] - nilai_gap_standar_pkl[i] for i in range(len(nilai_siswa))]
        return [self.gap(selisih_gap) for selisih_gap in selisih_profil_pkl]

    def pengurutan_penempatan(self, sub_aspek, jenis_pkl):
        hasil_bobot_gap = self.selisih(sub_aspek, jenis_pkl)

        cf = [hasil_bobot_gap[i] for i in range(7) if i != 2]
        sf = hasil_bobot_gap[7:10] + [hasil_bobot_gap[2]]  
        aspek_cf = sum(cf) / len(cf) 
        aspek_sf = sum(sf) / len(sf)
        total_aspek_1 = (aspek_cf * 0.6) + (aspek_sf * 0.4)

        nfl = hasil_bobot_gap[10]  
        total_aspek_2 = nfl 

        return (total_aspek_1 * 0.6) + (total_aspek_2 * 0.4)

    def inference(self, sub_aspek_data):
        nilai_penempatan = {}

        for jenis_pkl in ["Mobile Engineering", "Software Engineering", "Internet of Things"]:
            nilai_penempatan[jenis_pkl] = self.pengurutan_penempatan(sub_aspek_data, jenis_pkl)

        kategori_terbaik = max(nilai_penempatan, key=nilai_penempatan.get)
        total = nilai_penempatan[kategori_terbaik]

        return total, kategori_terbaik
    
"""

# Save to file
file_path = 'pklplacementmodel.py'
with open(file_path, 'w') as file:
    file.write(model_script)

print(f"Model has been saved as {file_path}")
# Out:
# Model has been saved as pklplacementmodel.py
